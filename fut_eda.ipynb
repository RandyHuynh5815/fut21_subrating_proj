# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("clean_fut21_data.csv")

# %%
df
# Out:
#         PAC   SHO   PAS   DRI   DEF   PHY   DIV   HAN   KIC   REF   SPE   POS  \
# 0      85.0  92.0  91.0  95.0  38.0  65.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1      89.0  93.0  81.0  89.0  35.0  77.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2      78.0  91.0  78.0  86.0  43.0  82.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3      91.0  85.0  86.0  94.0  36.0  59.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4      76.0  86.0  93.0  88.0  64.0  78.0   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 17480   NaN   NaN   NaN   NaN   NaN   NaN  49.0  51.0  44.0  50.0  22.0  45.0
# 17481   NaN   NaN   NaN   NaN   NaN   NaN  51.0  47.0  43.0  48.0  33.0  46.0
# 17482   NaN   NaN   NaN   NaN   NaN   NaN  49.0  47.0  45.0  46.0  54.0  44.0
# 17483   NaN   NaN   NaN   NaN   NaN   NaN  51.0  47.0  43.0  48.0  33.0  46.0
# 17484   NaN   NaN   NaN   NaN   NaN   NaN  47.0  46.0  46.0  50.0  22.0  45.0
#
# ...

# %% [markdown]
# # Overall Rating Distribution and Rarity Counts

# %%
sns.displot(data=df, x='Rtg', kde=True)
plt.title("Overall Rating Distrubution")
plt.show()

# %%
df['Rarity'].value_counts()
# Out:
# Silver    8770
# Bronze    6596
# Gold      2119
# Name: Rarity, dtype: int64

# %%
fig, ax = plt.subplots()
labels, count = np.unique(df['Rarity'], return_counts=True)
ax.pie(count, labels=labels, colors=['#CD7F32','#FFD700','#808080'], autopct=lambda x: '{:.2f}%'.format(x))
plt.title("Card Rarity Proportions")
plt.show()

# %% [markdown]
# # Position Counts

# %%
df['Position'].value_counts()
# Out:
# Midfielder    6582
# Defender      5730
# Attacker      3364
# Goalkeeper    1809
# Name: Position, dtype: int64

# %%
fig, ax = plt.subplots()
labels, count = np.unique(df['Position'], return_counts=True)
ax.pie(count, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
plt.title("Position Distribution")
plt.show()

# %% [markdown]
# # General Subrating Distribution

# %%
df.describe()
# Out:
#                 PAC           SHO           PAS           DRI           DEF  \
# count  15676.000000  15676.000000  15676.000000  15676.000000  15676.000000
# mean      68.134473     53.333759     58.122799     63.404185     51.995854
# std       11.227059     13.934432     10.026379      9.587489     16.355728
# min       25.000000     16.000000     25.000000     26.000000     15.000000
# 25%       62.000000     43.000000     52.000000     58.000000     37.000000
# 50%       69.000000     56.000000     59.000000     64.000000     57.000000
# 75%       76.000000     64.000000     65.000000     70.000000     65.000000
# max       96.000000     93.000000     93.000000     95.000000     91.000000
#
#                 PHY          DIV          HAN          KIC          REF  \
# count  15676.000000  1809.000000  1809.000000  1809.000000  1809.000000
# mean      65.429382    66.154229    63.627418    62.424544    67.081813
# ...

# %% [markdown]
# ## Field Players (PAC, SHO,	PAS, DRI, DEF, PHY)

# %%
df.boxplot(column = ['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY'])
plt.show()

# %%
sns.displot(data=df, x='PAC', kde=True)
plt.title("General Pace Distribution Among Field Players")
plt.show()

# %%
sns.displot(data=df, x='SHO', kde=True)
plt.title("General Shooting Distribution Among Field Players")
plt.show()

# %%
sns.displot(data=df, x='PAS', kde=True)
plt.title("General Passing Distribution Among Field Players")
plt.show()

# %%
sns.displot(data=df, x='DRI', kde=True)
plt.title("General Dribbling Distribution Among Field Players")
plt.show()

# %%
sns.displot(data=df, x='DEF', kde=True)
plt.title("General Defending Distribution Among Field Players")
plt.show()

# %%
sns.displot(data=df, x='PHY', kde=True)
plt.title("General Physical Distribution Among Field Players")
plt.show()

# %% [markdown]
# ## Goalkeepers (DIV, HAN, KIC, REF, SPE, POS)

# %%
df.boxplot(column = ['DIV', 'HAN', 'KIC', 'REF', 'SPE', 'POS'])
plt.show()

# %%
sns.displot(data=df, x='DIV', kde=True)
plt.title("General Diving Distribution Goalkeepers")
plt.show()

# %%
sns.displot(data=df, x='HAN', kde=True)
plt.title("General Handling Distribution Among Goalkeepers")
plt.show()

# %%
sns.displot(data=df, x='KIC', kde=True)
plt.title("General Kicking Distribution Among Goalkeepers")
plt.show()

# %%
sns.displot(data=df, x='REF', kde=True)
plt.title("General Reflex Distribution Among Goalkeepers")
plt.show()

# %%
sns.displot(data=df, x='SPE', kde=True)
plt.title("General Speed Distribution Among Goalkeepers")
plt.show()

# %%
sns.displot(data=df, x='POS', kde=True)
plt.title("General Speed Distribution Among Goalkeepers")
plt.show()

# %% [markdown]
# ## Scaleable Ratings (WF and Skill)

# %%
df['WF'].value_counts(sort=False)
# Out:
# 1      107
# 2     3646
# 3    10686
# 4     2772
# 5      274
# Name: WF, dtype: int64

# %%
fig, ax = plt.subplots()
labels, count = np.unique(df['WF'], return_counts=True)
ax.pie(count, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
plt.title("Weak Foot Proportions")
plt.show()

# %%
df['Skill'].value_counts(sort=False)
# Out:
# 1    1809
# 2    7784
# 3    6666
# 4    1172
# 5      54
# Name: Skill, dtype: int64

# %%
fig, ax = plt.subplots()
labels, count = np.unique(df['Skill'], return_counts=True)
ax.pie(count, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
plt.title("Skill Moves Proportions")
plt.show()

# %% [markdown]
# # Ratings and Subratings Based on Position

# %%
pd.pivot_table(df, index=["Position"], values=['Rtg'], aggfunc=['count', np.mean, min, max])
# Out:
#            count       mean min max
#              Rtg        Rtg Rtg Rtg
# Position
# Attacker    3364  66.632878  47  93
# Defender    5730  66.663700  47  90
# Goalkeeper  1809  65.468214  48  91
# Midfielder  6582  66.694622  47  91

# %%
pd.pivot_table(df, index=["Position"], values=['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY'], aggfunc=[np.mean, min, max])
# Out:
#                  mean                                                         \
#                   DEF        DRI        PAC        PAS        PHY        SHO
# Position
# Attacker    32.042212  66.153389  71.762188  55.833829  64.147146  65.137337
# Defender    64.713264  57.388482  64.941710  53.592147  69.101222  40.882548
# Midfielder  51.122759  67.236098  69.059860  63.236858  62.888180  58.140535
#
#              min                                 max                          \
#              DEF   DRI   PAC   PAS   PHY   SHO   DEF   DRI   PAC   PAS   PHY
# Position
# Attacker    15.0  43.0  25.0  30.0  31.0  38.0  72.0  95.0  96.0  91.0  90.0
# Defender    42.0  26.0  29.0  25.0  39.0  16.0  91.0  88.0  96.0  87.0  89.0
# Midfielder  16.0  37.0  30.0  39.0  29.0  26.0  87.0  91.0  95.0  93.0  91.0
#
#
#              SHO
# Position
# Attacker    93.0
# Defender    77.0
# Midfielder  86.0

# %%
pd.pivot_table(df, index=["Position"], values=['DIV', 'HAN', 'KIC', 'REF', 'SPE', 'POS'], aggfunc=[np.mean, min, max])
# Out:
#                  mean                                                         \
#                   DIV        HAN        KIC        POS        REF        SPE
# Position
# Goalkeeper  66.154229  63.627418  62.424544  64.114981  67.081813  37.954118
#
#              min                                 max                          \
#              DIV   HAN   KIC   POS   REF   SPE   DIV   HAN   KIC   POS   REF
# Position
# Goalkeeper  46.0  45.0  35.0  38.0  46.0  13.0  90.0  92.0  93.0  91.0  90.0
#
#
#              SPE
# Position
# Goalkeeper  65.0

# %%
sns.displot(data=df, x='Rtg', kind='kde', hue="Position")
plt.title("Distribution of Overall Rating By Position")
# Out:
# Text(0.5, 1.0, 'Distribution of Overall Rating By Position')

# %%
sns.displot(data=df, x='PAC', kind='kde', hue="Position", hue_order=["Attacker", "Midfielder", "Defender"])
plt.title("Distribution of Pace By Position")
plt.show()

# %%
sns.displot(data=df, x='SHO', kind='kde', hue="Position", hue_order=["Attacker", "Midfielder", "Defender"])
plt.title("Distribution of Shooting By Position")
plt.show()

# %%
sns.displot(data=df, x='PAS', kind='kde', hue="Position", hue_order=["Attacker", "Midfielder", "Defender"])
plt.title("Distribution of Passing By Position")
plt.show()

# %%
sns.displot(data=df, x='DRI', kind='kde', hue="Position", hue_order=["Attacker", "Midfielder", "Defender"])
plt.title("Distribution of Dribbling By Position")
plt.show()

# %%
sns.displot(data=df, x='DEF', kind='kde', hue="Position", hue_order=["Attacker", "Midfielder", "Defender"])
plt.title("Distribution of Defense Rating By Position")
plt.show()

# %%
sns.displot(data=df, x='PHY', kind='kde', hue="Position", hue_order=["Attacker", "Midfielder", "Defender"])
plt.title("Distribution of Physical By Position")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))
p = [("Attacker", (0,0)), ("Midfielder", (0,1)), ("Defender",(1,0)), ("Goalkeeper", (1,1))]
for pos, loc in p:
    labels, count = np.unique(df['WF'][df['Position'] == pos], return_counts=True)
    x,y = loc
    
    ax[x][y].pie(count, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[x][y].set_title(f"Weak Foot of {pos}s")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=5,ncols=1, figsize=(5,15))
for i in range(5):
    labels, poscount = np.unique(df["Position"][df['Skill'] == (i+1)], return_counts=True)
    
    if i == 0:
        ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x), colors=['red'])
    else:
        ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[i].set_title(f"Positions of {i+1} Starred Skill Moves")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))
p = [("Attacker", (0,0)), ("Midfielder", (0,1)), ("Defender",(1,0)), ("Goalkeeper", (1,1))]
for pos, loc in p:
    labels, count = np.unique(df['Skill'][df['Position'] == pos], return_counts=True)
    x,y = loc
    
    ax[x][y].pie(count, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[x][y].set_title(f"Skill Moves of {pos}s")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=5,ncols=1, figsize=(5,15))
for i in range(5):
    labels, poscount = np.unique(df["Position"][df['Skill'] == (i+1)], return_counts=True)
    
    if i == 0:
        ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x), colors=['red'])
    else:
        ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[i].set_title(f"Positions of {i+1} Starred Skill Moves")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))
p = [("Attacker", (0,0)), ("Midfielder", (0,1)), ("Defender",(1,0)), ("Goalkeeper", (1,1))]
for pos, loc in p:
    labels, count = np.unique(df['Rarity'][df['Position'] == pos], return_counts=True)
    x,y = loc
    
    ax[x][y].pie(count, labels=labels, autopct=lambda x: '{:.2f}%'.format(x), colors=['#CD7F32','#FFD700','#808080'])
    ax[x][y].set_title(f"Quality of {pos}s")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Position and Subratings Based on Rarity

# %%
pd.pivot_table(df, index=["Rarity"], values=['Rtg'], aggfunc=['count', np.mean, min, max])
# Out:
#        count       mean min max
#          Rtg        Rtg Rtg Rtg
# Rarity
# Bronze  6596  59.881747  47  64
# Gold    2119  77.916470  75  93
# Silver  8770  68.810376  65  74

# %%
pd.pivot_table(df, index=["Rarity"], values=['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY'], aggfunc=[np.mean, min, max])
# Out:
#              mean                                                         \
#               DEF        DRI        PAC        PAS        PHY        SHO
# Rarity
# Bronze  46.216329  57.248050  66.158260  51.079217  60.395042  46.757497
# Gold    60.655063  74.357595  71.816983  70.073840  71.688291  65.083333
# Silver  54.108476  65.245038  68.686057  60.366621  67.573461  55.288728
#
#          min                                 max
#          DEF   DRI   PAC   PAS   PHY   SHO   DEF   DRI   PAC   PAS   PHY   SHO
# Rarity
# Bronze  15.0  26.0  25.0  25.0  29.0  17.0  69.0  73.0  94.0  72.0  86.0  71.0
# Gold    19.0  44.0  31.0  42.0  41.0  22.0  91.0  95.0  96.0  93.0  91.0  93.0
# Silver  17.0  32.0  30.0  29.0  31.0  16.0  80.0  81.0  95.0  80.0  89.0  80.0

# %%
pd.pivot_table(df, index=["Rarity"], values=['DIV', 'HAN', 'KIC', 'REF', 'SPE', 'POS'], aggfunc=[np.mean, min, max])
# Out:
#              mean                                                         \
#               DIV        HAN        KIC        POS        REF        SPE
# Rarity
# Bronze  59.920193  57.860943  57.045949  57.220073  60.461911  33.592503
# Gold    78.699552  75.721973  73.098655  77.659193  80.394619  46.327354
# Silver  69.260870  66.357049  65.148880  67.648221  70.383399  40.246377
#
#          min                                 max
#          DIV   HAN   KIC   POS   REF   SPE   DIV   HAN   KIC   POS   REF   SPE
# Rarity
# Bronze  46.0  45.0  35.0  38.0  46.0  13.0  71.0  70.0  72.0  69.0  73.0  63.0
# Gold    71.0  65.0  44.0  71.0  71.0  25.0  90.0  92.0  93.0  91.0  90.0  65.0
# Silver  60.0  54.0  44.0  53.0  59.0  15.0  81.0  76.0  90.0  82.0  82.0  62.0

# %%
sns.displot(data=df, x='Rtg', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Overall Rating By Rarity")
plt.show()

# %% [markdown]
# ## Field Players

# %%
sns.displot(data=df, x='PAC', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Pace By Rarity")
plt.show()

# %%
sns.displot(data=df, x='SHO', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Shooting By Rarity")
plt.show()

# %%
sns.displot(data=df, x='PAS', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Passing By Rarity")
plt.show()

# %%
sns.displot(data=df, x='DRI', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Dribbling By Rarity")
plt.show()

# %%
sns.displot(data=df, x='DEF', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Defending By Rarity")
plt.show()

# %%
sns.displot(data=df, x='PHY', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Physicality By Rarity")
plt.show()

# %% [markdown]
# ## Goalkeepers

# %%
sns.displot(data=df, x='DIV', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Diving By Rarity")
plt.show()

# %%
sns.displot(data=df, x='HAN', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of HandlingRE By Rarity")
plt.show()

# %%
sns.displot(data=df, x='KIC', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Kicking By Rarity")
plt.show()

# %%
sns.displot(data=df, x='REF', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Reflexes By Rarity")
plt.show()

# %%
sns.displot(data=df, x='SPE', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Speed By Rarity")
plt.show()

# %%
sns.displot(data=df, x='POS', kind='kde', hue="Rarity", palette=['#FFD700','#808080','#CD7F32'])
plt.title("Distribution of Positioning By Rarity")
plt.show()

# %% [markdown]
# ## Scalable Ratings

# %%
quality = ["Bronze", "Silver", "Gold"]
fig, ax = plt.subplots(nrows=1,ncols=3, figsize=(10,3))
for i,q in enumerate(quality):
    labels, poscount = np.unique(df["WF"][df['Rarity'] == q], return_counts=True)
    
    ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[i].set_title(f"Weak Foot of {q} Rated Players")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=5,ncols=1, figsize=(5,15))
for i in range(5):
    labels, poscount = np.unique(df["Rarity"][df['WF'] == (i+1)], return_counts=True)
    
    ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x), colors=['#CD7F32','#FFD700','#808080'])
    ax[i].set_title(f"Rarity of {i+1} Starred Weak Foot")
plt.tight_layout()
plt.show()

# %%
quality = ["Bronze", "Silver", "Gold"]
fig, ax = plt.subplots(nrows=1,ncols=3, figsize=(10,3))
for i,q in enumerate(quality):
    labels, poscount = np.unique(df["Skill"][df['Rarity'] == q], return_counts=True)
    
    ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[i].set_title(f"Skill Moves of {q} Rated Players")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=5,ncols=1, figsize=(5,15))
for i in range(5):
    labels, poscount = np.unique(df["Rarity"][df['Skill'] == (i+1)], return_counts=True)
    
    if i == 4:
        ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x), colors=['#FFD700','#808080'])
    else:
        ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x), colors=['#CD7F32','#FFD700','#808080'])
    ax[i].set_title(f"Rarity of {i+1} Starred Skill Moves")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Positions Based On Rarity

# %%
quality = ["Bronze", "Silver", "Gold"]
fig, ax = plt.subplots(nrows=1,ncols=3, figsize=(10,3))
for i,q in enumerate(quality):
    labels, poscount = np.unique(df["Position"][df['Rarity'] == q], return_counts=True)
    
    ax[i].pie(poscount, labels=labels, autopct=lambda x: '{:.2f}%'.format(x))
    ax[i].set_title(f"Positions of {q} Rated Players")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Combining Rarity and Position

# %%
pd.pivot_table(df, index=["Rarity", "Position"], values=['Rtg'], aggfunc=['count', np.mean, min, max])
# Out:
#                   count       mean min max
#                     Rtg        Rtg Rtg Rtg
# Rarity Position
# Bronze Attacker    1304  59.855061  47  64
#        Defender    2066  60.338819  47  64
#        Goalkeeper   827  58.980653  48  64
#        Midfielder  2399  59.813256  47  64
# Gold   Attacker     448  78.125000  75  93
#        Defender     621  77.689211  75  90
#        Goalkeeper   223  78.529148  75  91
#        Midfielder   827  77.808948  75  91
# Silver Attacker    1612  68.921836  65  74
#        Defender    3043  68.707854  65  74
#        Goalkeeper   759  68.699605  65  74
#        Midfielder  3356  68.874851  65  74

# %%
pd.pivot_table(df, index=["Rarity", "Position"], values=['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY'], aggfunc=[np.mean, min, max])
# Out:
#                         mean                                              \
#                          DEF        DRI        PAC        PAS        PHY
# Rarity Position
# Bronze Attacker    27.811350  59.582055  69.431748  48.328221  59.112730
#        Defender    58.301065  51.200871  62.995160  46.442401  64.545983
#        Midfielder  45.813256  61.187161  67.102960  56.567737  57.517299
# Gold   Attacker    38.946429  77.372768  75.705357  68.533482  70.904018
#        Defender    76.386473  68.041868  69.586151  65.172303  75.083736
#        Midfielder  60.602177  77.466747  71.385732  74.588875  69.563482
# Silver Attacker    33.545906  68.351117  72.551489  58.375931  66.341811
#        Defender    66.684522  59.415380  65.315478  56.083142  70.973053
#        Midfielder  52.582241  69.039035  69.885578  65.206794  65.082539
#
#                                min                                 max        \
# ...

# %% [markdown]
# # Subrating Correlation

# %% [markdown]
# Code from https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e

# %%
df_field_corr = df[['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'WF', 'Skill']].corr()
sns.heatmap(df_field, vmin=-1, vmax=1, annot=True, cmap='BrBG')
# Out:
# <AxesSubplot:>

# %%
df_gk_corr = df[['DIV', 'HAN', 'KIC', 'REF', 'SPE', 'POS']].corr()
sns.heatmap(df_gk_corr, vmin=-1, vmax=1, annot=True, cmap='BrBG')
# Out:
# <AxesSubplot:>
